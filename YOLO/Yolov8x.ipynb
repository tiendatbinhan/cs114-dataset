# %% [markdown]
# > **DEMO DETECT BY YOLOv8**
#
#
#
# Nhóm: Fusionist
#
# 20520184 - Nguyễn Trung Hiếu
#
# 20520991 - Đặng Văn Duy
#
# 21522124 - Phạm Văn Hùng
#
# 21520707 - Nguyễn Tiến Đạt

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # ***SetUp library***

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.2/166.8 GB disk)

# %% [markdown]
# - Unzip file data.zip để chuẩn bị cho việc train

# %%
path_to_directory = '/content/'
# !unzip '/content/gdrive/MyDrive/Data/Data_Train.zip'
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: Data_detect/train/labels/5727_angle_50.txt
#   inflating: Data_detect/train/labels/5727_angle_70.txt
#   inflating: Data_detect/train/labels/57726.txt
#   inflating: Data_detect/train/labels/57726_angle_10.txt
#   inflating: Data_detect/train/labels/57726_angle_30.txt
#   inflating: Data_detect/train/labels/57726_angle_50.txt
#   inflating: Data_detect/train/labels/57726_angle_70.txt
#   inflating: Data_detect/train/labels/57733_angle_10.txt
#   inflating: Data_detect/train/labels/57733_angle_50.txt
#   inflating: Data_detect/train/labels/57733_angle_70.txt
#   inflating: Data_detect/train/labels/57850.txt
#   inflating: Data_detect/train/labels/57850_angle_30.txt
#   inflating: Data_detect/train/labels/57850_angle_70.txt
#   inflating: Data_detect/train/labels/58158.txt
#   inflating: Data_detect/train/labels/58158_angle_10.txt
#   inflating: Data_detect/train/labels/58158_angle_30.txt
# ...

# %% [markdown]
# # PHIÊN BẢN ***YOLOv8n***

# %% [markdown]
# ## Train model

# %% [markdown]
# - Thực hiện việc train model với phiên bản nhỏ nhất của YOLOv8, với dataset bên trên và epochs bằng 50, đồng thời sử dụng seed cho quá trình train

# %%
# Train YOLOv8n on COCO128 for 50 epochs
# !yolo mode=train model=yolov8n.pt data=/content/Data_detect/coco128.yaml epochs=50 imgsz=640 seed = 123 device=0
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 146MB/s]
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Evaluate Val

# %% [markdown]
# - Sau khi quá trình train kết thúc, ta lấy đường dẫn file trọng số model vừa train trong thư mục runs/detect/train/weights/best.pt.
# - Chúng ta cũng có thể sử dụng file last.pt cho việc trên, và tại sao lại là train ? Thì trong mục runs/detect sẽ có nhiều thư mục train, ví dụ như train, train 2, train 3... tuỳ thuộc theo số lần chúng ta train model.

# %%
# !yolo mode = val model = /content/runs/detect/train/weights/best.pt data=/content/Data_detect/coco128.yaml conf = 0.25 imgsz=640 split = test device=0
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3016568 parameters, 0 gradients
# val: Scanning /content/Data_detect/test/labels... 558 images, 0 backgrounds, 0 corrupt: 100% 558/558 [00:00<00:00, 1624.83it/s]
# val: New cache created: /content/Data_detect/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:09<00:00,  3.64it/s]
#                    all        558        705       0.93      0.966      0.955      0.907
#                  3mien        558         27          1          1      0.995       0.98
#                    7up        558         13          1          1      0.995      0.946
#                    247        558         10          1          1      0.995      0.978
#              Ajinomoto        558         16      0.946          1      0.995      0.836
# ...

# %% [markdown]
# *   Sau khi có kết quả, ta sẽ tiến hành đánh giá trong báo cáo

# %% [markdown]
# # PHIÊN BẢN ***YOLOv8x***

# %% [markdown]
# ## Train model

# %%
# !yolo mode=train model=yolov8x.pt data=/content/Data_detect/coco128.yaml epochs=50 imgsz=640 seed = 123 device=0
# Out:
# ...
# 100% 131M/131M [00:03<00:00, 35.5MB/s]
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Evaluate Val

# %% [markdown]
# - Sau khi quá trình train kết thúc, ta lấy đường dẫn file trọng số model vừa train trong thư mục runs/detect/train2/weights/best.pt.
# - Chúng ta cũng có thể sử dụng file last.pt cho việc trên, và tại sao lại là train ? Thì trong mục runs/detect sẽ có nhiều thư mục train, ví dụ như train, train 2, train 3... tuỳ thuộc theo số lần chúng ta train model.

# %%
# !yolo mode = val model = /content/runs/detect/train/weights/best.pt data=/content/Data_detect/coco128.yaml conf = 0.25 imgsz=640 split = test device=0
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68177496 parameters, 0 gradients
# val: Scanning /content/Data_detect/test/labels... 558 images, 0 backgrounds, 0 corrupt: 100% 558/558 [00:00<00:00, 1556.72it/s]
# val: New cache created: /content/Data_detect/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:39<00:00,  1.13s/it]
#                    all        558        705      0.978      0.996      0.992      0.949
#                  3mien        558         27          1          1      0.995      0.994
#                    7up        558         13          1          1      0.995      0.968
#                    247        558         10          1          1      0.995      0.968
#              Ajinomoto        558         16          1      0.938      0.969      0.837
# ...

# %% [markdown]
# ## Predict example

# %%
# !yolo mode = predict model = /content/runs/detect/train/weights/best.pt source = '/content/data (260).jpg'
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68177496 parameters, 0 gradients
#
# image 1/1 /content/data (260).jpg: 640x640 1 Dasani, 1 Haohao, 1 Namngu, 1 Salt, 97.7ms
# Speed: 4.0ms preprocess, 97.7ms inference, 95.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5

# %% [markdown]
# # **KẾT LUẬN**

# %% [markdown]
# - Dựa trên kết quả thu được từ việc train và dự đoán trên 2 phiên bản của YOLOv8 thì ta nhận thấy với dataset nhỏ và vừa thì 2 phiên bản cho kết quả không quá khác biệt, nhưng với model YOLOv8x thì ta cần tới 68.2(M) params và 4.524 hours để train model, còn với YOLOv8n thì chỉ có 3.2(M) params và 0.936 hours để train. Từ đó, ta có thể đưa ra quyết định về model để mang vào sử dụng trong thực tế.
# - Kết quả, ta thấy có 3-4 class cho kết quả chưa tốt, nguyên nhân dẫn đến điều này là vì hình ảnh chụp của các class này không rõ hay là quá xấu cho việc train model, nên đã loại bỏ khá nhiều ra khỏi bộ dataset ban đầu để cho model trở nên tốt hơn, cho nên số lượng hình ảnh thuộc vào những class trên hơn ít khiến cho kết quả cho những class này chưa tốt. Để khắc phục điều này, ta sẽ bổ sung thêm data của những lớp nói trên vào bộ dataset sau để cho kết quả tốt hơn.
